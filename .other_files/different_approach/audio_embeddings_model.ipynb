# %%
pip install torchvggish
# Out:
# Requirement already satisfied: torchvggish in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (0.2)
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from torchvggish) (2.3.4)
# Requirement already satisfied: torch in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from torchvggish) (2.5.1+cu121)
# Requirement already satisfied: resampy in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from torchvggish) (0.4.3)
# Requirement already satisfied: numba>=0.53 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from resampy->torchvggish) (0.62.1)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from numba>=0.53->resampy->torchvggish) (0.45.1)
# Requirement already satisfied: filelock in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from torch->torchvggish) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from torch->torchvggish) (4.15.0)
# Requirement already satisfied: networkx in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from torch->torchvggish) (3.5)
# Requirement already satisfied: jinja2 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from torch->torchvggish) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from torch->torchvggish) (2025.10.0)
# Requirement already satisfied: setuptools in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from torch->torchvggish) (80.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from torch->torchvggish) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch->torchvggish) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch->torchvggish) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import torch
import torchaudio
from torchvggish import vggish, vggish_input
import numpy as np
from tqdm import tqdm

model = vggish()
model.eval()

audio_folder = "../../data/input.data"
embeddings = {}

for fname in tqdm(os.listdir(audio_folder), desc="Processing audios"):
    if fname.endswith(".wav"):
        path = os.path.join(audio_folder, fname)
        waveform, sr = torchaudio.load(path)
        if waveform.shape[0] > 1:
            waveform = waveform.mean(dim=0, keepdim=True)
        if sr != 16000:
            waveform = torchaudio.transforms.Resample(sr, 16000)(waveform)
        if waveform.shape[1] < 16000:
            pad_len = 16000 - waveform.shape[1]
            waveform = torch.nn.functional.pad(waveform, (0, pad_len))
        torchaudio.save("tmp.wav", waveform, 16000)
        examples = vggish_input.wavfile_to_examples("tmp.wav")
        if examples.size == 0:
            continue
        with torch.no_grad():
            embs = model(torch.tensor(examples))
        embeddings[fname] = embs.mean(dim=0).cpu().numpy()
# Out:
# Processing audios:   0%|                                                                       | 0/500 [00:00<?, ?it/s]C:\Users\user\AppData\Local\Temp\ipykernel_18504\3750398624.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   embs = model(torch.tensor(examples))
# Processing audios: 100%|█████████████████████████████████████████████████████████████| 500/500 [00:44<00:00, 11.29it/s]

# %%
save_folder = "input_data_embeddings"
os.makedirs(save_folder, exist_ok=True)

for fname, emb in embeddings.items():
    save_path = os.path.join(save_folder, fname.replace(".wav", ".npy"))
    np.save(save_path, emb)
